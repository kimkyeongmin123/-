# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\kin\lib\site-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user\anaconda3\envs\kin\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\envs\kin\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\user\anaconda3\envs\kin\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\kin\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np
data = np.array([
    [1,'Alice', 30],
    [2,'Bob',25],
    [3,'Charlie',35]])

# %%
df =pd.DataFrame(data)

# %%
df = pd.DataFrame(data, columns=['ID','Name','Age'])

# %%
df= pd.read_csv("C:/Users/User/Desktop/Data/test.csv", header=0, encoding='cp949')

# %%
df.shape
# Out:
# (3, 3)

# %%
df=pd.read_csv("C:/Users/User/Desktop/Data/국영수.csv",encoding='cp949')

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['국어', '영어', '수학', '체육'], dtype='object')

# %%
df.dtypes
# Out:
# 국어     int64
# 영어     int64
# 수학     int64
# 체육    object
# dtype: object

# %%
df.describe()
# Out:
#               국어         영어         수학
# count   9.000000   9.000000   9.000000
# mean   65.888889  65.666667  53.000000
# std    17.467430  25.729361  28.583212
# min    41.000000  22.000000  13.000000
# 25%    54.000000  47.000000  21.000000
# 50%    61.000000  65.000000  54.000000
# 75%    84.000000  87.000000  78.000000
# max    87.000000  98.000000  87.000000

# %%
df.head()
# Out:
#    국어  영어  수학 체육
# 0  50  88  21  상
# 1  41  87  54  중
# 2  85  65  84  상
# 3  61  85  13  중
# 4  54  41  21  하

# %%
df.tail()
# Out:
#    국어  영어  수학 체육
# 4  54  41  21  하
# 5  84  47  87  하
# 6  77  98  65  상
# 7  87  58  54  중
# 8  54  22  78  히

# %%
df.isnull().sum()
# Out:
# 국어    0
# 영어    0
# 수학    0
# 체육    0
# dtype: int64

# %%
df['체육'].value_counts()
# Out:
# 중    3
# 상    3
# 하    2
# 히    1
# Name: 체육, dtype: int64

# %%
df['체육'].unique()
# Out:
# array(['상', '중', '하', '히'], dtype=object)

# %%
df['체육'].nunique()
# Out:
# 4

# %%
df["합계"]=df["국어"]+df["영어"]+df["수학"]

# %%
df["합계"]
# Out:
# 0    159
# 1    182
# 2    234
# 3    159
# 4    116
# 5    218
# 6    240
# 7    199
# 8    154
# Name: 합계, dtype: int64

# %%
df = df.drop(['체육'], axis=1)

# %%
df
# Out:
#    국어  영어  수학   합계
# 0  50  88  21  159
# 1  41  87  54  182
# 2  85  65  84  234
# 3  61  85  13  159
# 4  54  41  21  116
# 5  84  47  87  218
# 6  77  98  65  240
# 7  87  58  54  199
# 8  54  22  78  154

# %%
columns = ['column_a','column_b','column_c']

# %%
columns
# Out:
# ['column_a', 'column_b', 'column_c']

# %%
data={
    'A':[1,2,3,4],
    'B':[4.1,3.5,2.1,5.7],
    'C':['one','two','three','four']
}

# %%
df = pd.DataFrame(data)

# %%
df['A'].astype('category')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: A, dtype: category
# Categories (4, int64): [1, 2, 3, 4]

# %%
df['A']=df['A'].astype('str')

# %%
df['A'].astype('category')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: A, dtype: category
# Categories (4, object): ['1', '2', '3', '4']

# %%
df = df.rename(columns={'old_name':'new_name'})

# %%
df = df.rename(columns={
    'old_name1':'new_name1',
    'old_name2':'new_name2',
    'old_name3':'new_name3'
})

# %%
df
# Out:
#    A    B      C
# 0  1  4.1    one
# 1  2  3.5    two
# 2  3  2.1  three
# 3  4  5.7   four

# %%
data = {
    'Numeric1':[1,np.nan,3,4],
    'Numeric2':[5,6,np.nan,8.2],
    'Category':['dog',np.nan,'cat','dog']
}

# %%
df = pd.DataFrame(data)

# %%
A=df.select_dtypes(include=["number"]).columns

# %%
B=df.select_dtypes(include=['object','category']).columns

# %%
df[A].fillna(df[A].median())
# Out:
#    Numeric1  Numeric2
# 0       1.0       5.0
# 1       3.0       6.0
# 2       3.0       6.0
# 3       4.0       8.2

# %%
A
# Out:
# Index(['Numeric1', 'Numeric2'], dtype='object')

# %%
df[A].fillna(df[A].mean())
# Out:
#    Numeric1  Numeric2
# 0  1.000000       5.0
# 1  2.666667       6.0
# 2  3.000000       6.4
# 3  4.000000       8.2

# %%
df.fillna(df.median)
# Out:
#                                             Numeric1  \
# 0                                                  1
# 1  <bound method DataFrame.median of    Numeric1 ...
# 2                                                  3
# 3                                                  4
#
#                                             Numeric2  \
# 0                                                  5
# 1                                                  6
# 2  <bound method DataFrame.median of    Numeric1 ...
# 3                                                8.2
#
#                                             Category
# 0                                                dog
# 1  <bound method DataFrame.median of    Numeric1 ...
# 2                                                cat
# 3                                                dog

# %%
df1=pd.DataFrame({
    'a':['a0','a1','a2','a3'],
    'b':['b0','b1','b2','b3'],
    'c':['c0','c1','c2','c3']
})

# %%
df2=pd.DataFrame({
    'a':['a2','a3','a4','a5'],
    'b':['b2','b3','b4','b5'],
    'c':['c2','c3','c4','c5']
})

# %%
pd.concat([df1,df2], axis=0)
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 0  a2  b2  c2
# 1  a3  b3  c3
# 2  a4  b4  c4
# 3  a5  b5  c5

# %%
pd.concat([df1,df2], axis=1)
# Out:
#     a   b   c   a   b   c
# 0  a0  b0  c0  a2  b2  c2
# 1  a1  b1  c1  a3  b3  c3
# 2  a2  b2  c2  a4  b4  c4
# 3  a3  b3  c3  a5  b5  c5

# %%
pd.concat([df[A],df[B]], axis=0)
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      NaN
# 1       NaN       6.0      NaN
# 2       3.0       NaN      NaN
# 3       4.0       8.2      NaN
# 0       NaN       NaN      dog
# 1       NaN       NaN      NaN
# 2       NaN       NaN      cat
# 3       NaN       NaN      dog

# %%
pd.concat([df[A],df[B]], axis=1)
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 2       3.0       NaN      cat
# 3       4.0       8.2      dog

# %%
data = {
    'Numeric1':[1,np.nan,3,4],
    'Numeric2':[5,6,np.nan,8.2],
    'Category':['dog',np.nan,'cat','dog']
}

# %%
df = pd.DataFrame(data)

# %%
df[0:2]
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN

# %%
df[:2]
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN

# %%
df[(df['Numeric2']>=6)&(df['Numeric2']<=10)]
df[(df['Numeric2']>=6)|(df['Numeric2']<=10)]
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog

# %%
df[(df['Numeric2']>=6)&(df['Numeric2']<=10)]
# Out:
#    Numeric1  Numeric2 Category
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog

# %%
df[(df['Numeric2']>=6)|(df['Numeric2']<=10)]
# Out:
#    Numeric1  Numeric2 Category
# 0       1.0       5.0      dog
# 1       NaN       6.0      NaN
# 3       4.0       8.2      dog
