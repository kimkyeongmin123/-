# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
random_image = np.random.randint(0, 256, (100, 100), dtype=np.uint8)

# %%
plt.figure(figsize=(12, 4))

# %%
plt.imshow(random_image)

# %%
random_image = np.random.randint(0, 256, (100, 100), dtype=np.uint8)

# %%
RGB_image = cv2.cvtColor(random_image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(12, 4))

# %%
plt.imshow(RGB_image)

# %%
image = cv2.imread("C:/Users/User/Downloads/download.jpg")

# %%
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(12,4))

# %%
plt.imshow(image)

# %%
R, G, B = cv2.split(RGB_image)

# %%
plt.figure(figsize=(12,4))

# %%
#빨간 채널
plt.subplot(1,3,1)
plt.imshow(R, cmap='Reds')
plt.title('Red Channel')
# Out:
# Text(0.5, 1.0, 'Red Channel')

# %%
#초록 채널
plt.subplot(1,3,2)
plt.imshow(G, cmap='Greens')
plt.title('Green Channel')
# Out:
# Text(0.5, 1.0, 'Green Channel')

# %%
#파란 채널
plt.subplot(1,3,3)
plt.imshow(B, cmap='Blues')
plt.title('Blue Channel')
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
image_hsv = cv2. cvtColor(RGB_image, cv2.COLOR_RGB2HSV)

# %%
H, S, V = cv2.split(image_hsv)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(H, cmap='hsv')
plt.title('Hue Channel')
# Out:
# Text(0.5, 1.0, 'Hue Channel')

# %%
plt.subplot(1,3,2)
plt.imshow(S, cmap='gray') 
plt.title('Saturation Channel')
# Out:
# Text(0.5, 1.0, 'Saturation Channel')

# %%
plt.subplot(1,3,3)
plt.imshow(V, cmap='gray')
plt.title('Value Channel')
# Out:
# Text(0.5, 1.0, 'Value Channel')

# %%
plt.show()

# %%
image = cv2.imread("C:/Users/User/Desktop/Data/download.jpg")
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,4))
plt.imshow(image)

# %%
image = cv2.imread("C:/Users/User/Desktop/Data/download.jpg")
RGB_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(image,(64,64))
plt.figure(figsize=(12,4))
plt.imshow(resized_image)

# %%
resized_image = cv2.resize(image,(64,64),
interpolation=cv2.INTER_AREA)
plt.imshow(resized_image)
