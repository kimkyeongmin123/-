# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/User/Desktop/실습데이터/sample_1.csv", header=0, encoding='utf-8')

# %%
df
# Out:
#               연구번호      입실일자    입실시각    검사코드  \
# 0       1219300234  20210220  1350.0  ZF0156
# 1       1219300234  20210220  1350.0  ZF0016
# 2       1219300234  20210220  1350.0  ZF0155
# 3       1219300234  20210220  1350.0  BB0007
# 4       1219300234  20210220  1350.0  ZF0012
# ...            ...       ...     ...     ...
# 799995  1169043575  20200519  1800.0  ZF0157
# 799996  1169043575  20200519  1800.0  BC0202
# 799997  1169043575  20200519  1800.0  ZF0014
# 799998  1169043575  20200519  1800.0  ZF0016
# 799999  1169043575  20200519  1800.0  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# 4              O2 saturation (Qn),Artery blood       98.3
# ...                                        ...        ...
# ...

# %%
df['입실일자']=pd.to_datetime(df['입실일자'],format='%Y%m%d', errors='coerce')

# %%
df
# Out:
#               연구번호       입실일자    입실시각    검사코드  \
# 0       1219300234 2021-02-20  1350.0  ZF0156
# 1       1219300234 2021-02-20  1350.0  ZF0016
# 2       1219300234 2021-02-20  1350.0  ZF0155
# 3       1219300234 2021-02-20  1350.0  BB0007
# 4       1219300234 2021-02-20  1350.0  ZF0012
# ...            ...        ...     ...     ...
# 799995  1169043575 2020-05-19  1800.0  ZF0157
# 799996  1169043575 2020-05-19  1800.0  BC0202
# 799997  1169043575 2020-05-19  1800.0  ZF0014
# 799998  1169043575 2020-05-19  1800.0  ZF0016
# 799999  1169043575 2020-05-19  1800.0  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# 4              O2 saturation (Qn),Artery blood       98.3
# ...

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#               연구번호       입실일자    입실시각    검사코드  \
# 0       1219300234 2021-02-20  1350.0  ZF0156
# 1       1219300234 2021-02-20  1350.0  ZF0016
# 2       1219300234 2021-02-20  1350.0  ZF0155
# 3       1219300234 2021-02-20  1350.0  BB0007
# 4       1219300234 2021-02-20  1350.0  ZF0012
# ...            ...        ...     ...     ...
# 799995  1169043575 2020-05-19  1800.0  ZF0157
# 799996  1169043575 2020-05-19  1800.0  BC0202
# 799997  1169043575 2020-05-19  1800.0  ZF0014
# 799998  1169043575 2020-05-19  1800.0  ZF0016
# 799999  1169043575 2020-05-19  1800.0  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# 4              O2 saturation (Qn),Artery blood       98.3
# ...

# %%
df1['입실시각']=pd.to_datetime(df1['입실시각'], format='%H%M' , errors='coerce').dt.time

# %%
df1
# Out:
#               연구번호       입실일자      입실시각    검사코드  \
# 0       1219300234 2021-02-20  13:50:00  ZF0156
# 1       1219300234 2021-02-20  13:50:00  ZF0016
# 2       1219300234 2021-02-20  13:50:00  ZF0155
# 3       1219300234 2021-02-20  13:50:00  BB0007
# 4       1219300234 2021-02-20  13:50:00  ZF0012
# ...            ...        ...       ...     ...
# 799995  1169043575 2020-05-19  18:00:00  ZF0157
# 799996  1169043575 2020-05-19  18:00:00  BC0202
# 799997  1169043575 2020-05-19  18:00:00  ZF0014
# 799998  1169043575 2020-05-19  18:00:00  ZF0016
# 799999  1169043575 2020-05-19  18:00:00  BB0074
#
#                                         검사코드NM  검사결과값(숫자)  \
# 0               ABGA coding (Des),Artery blood      342.0
# 1                Bicarbonate (Qn),Artery blood       27.5
# 2       ABGA interpretation (Des),Artery blood        NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8
# 4              O2 saturation (Qn),Artery blood       98.3
# ...

# %%
df1['접수일자']=pd.to_datetime(df1['접수일자'], format='%Y%m%d', errors='coerce')

# %%
df1['퇴실일자']=pd.to_datetime(df1['퇴실일자'], format='%Y%m%d', errors='coerce')

# %%
df1['퇴실시각']=df1['퇴실시각'].astype(str)

# %%
df1['퇴실시각']=pd.to_datetime(df1['퇴실시각'].str.ljust(6, fillchar="0"), format='%H%M%S', errors='coerce').dt.time

# %%
df1=df1.drop(['검사코드'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df1=df1.drop(['검사코드'],axis=1)
#
# File ~\anaconda3\envs\bin\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df1=df1.drop(['검사결과값(표시)'],axis=1)

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...

# %%
df1=df1.drop(['진료과코드'],axis=1)

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...

# %%
df1.dropna()
# Out:
#               연구번호       입실일자      입실시각                           검사코드NM  \
# 1       1219300234 2021-02-20  13:50:00    Bicarbonate (Qn),Artery blood
# 3       1219300234 2021-02-20  13:50:00        pO2 (Qn)[EM],Artery blood
# 4       1219300234 2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 5       1219300234 2021-02-20  13:50:00  O2 saturation (Qn),Artery blood
# 9       1219300234 2021-02-20  13:50:00       pCO2 (Qn)[EM],Artery blood
# ...            ...        ...       ...                              ...
# 799991  1169043575 2020-05-19  18:00:00        pO2 (Qn)[EM],Artery blood
# 799992  1169043575 2020-05-19  18:00:00       pCO2 (Qn)[EM],Artery blood
# 799993  1169043575 2020-05-19  18:00:00         Glucose (Qn)[POCT],Blood
# 799996  1169043575 2020-05-19  18:00:00         Glucose (Qn)[POCT],Blood
# 799998  1169043575 2020-05-19  18:00:00    Bicarbonate (Qn),Artery blood
#
#         검사결과값(숫자)  기준치상한값  기준치하한값       접수일자      접수시각  검사나이  진료과코드NM  \
# ...

# %%
df1['연구번호']=df1['연구번호'].astype(str)

# %%
df1['환자ID']=df1['연구번호'].str[:3] + df1['연구번호'].str[-5:]

# %%
df1['검사나이'] = df1['검사나이'] -1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\bin\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\envs\bin\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\envs\bin\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# ...

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...

# %%
df1['검사나이']=df1['검사나이'].astype(str)

# %%
df1["입원기간"]=df1["퇴실일자"] - df1["입실일자"]

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...

# %%
df1=df1.drop(['성별코드NM'],axis=1)

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...

# %%
df1=df1.drop(['진료과코드NM'],axis=1)

# %%
df1
# Out:
#               연구번호       입실일자      입실시각  \
# 0       1219300234 2021-02-20  13:50:00
# 1       1219300234 2021-02-20  13:50:00
# 2       1219300234 2021-02-20  13:50:00
# 3       1219300234 2021-02-20  13:50:00
# 4       1219300234 2021-02-20  13:50:00
# ...            ...        ...       ...
# 799995  1169043575 2020-05-19  18:00:00
# 799996  1169043575 2020-05-19  18:00:00
# 799997  1169043575 2020-05-19  18:00:00
# 799998  1169043575 2020-05-19  18:00:00
# 799999  1169043575 2020-05-19  18:00:00
#
#                                         검사코드NM  검사결과값(숫자)  기준치상한값  기준치하한값  \
# 0               ABGA coding (Des),Artery blood      342.0     NaN     NaN
# 1                Bicarbonate (Qn),Artery blood       27.5    29.0    23.0
# 2       ABGA interpretation (Des),Artery blood        NaN     NaN     NaN
# 3                    pO2 (Qn)[EM],Artery blood      117.8   108.0    83.0
# 4              O2 saturation (Qn),Artery blood       98.3   100.0    94.0
# ...
